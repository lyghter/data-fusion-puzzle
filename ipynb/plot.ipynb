# %%
# import pandas as pd
# df=pd.DataFrame()
# df['a']=[1,2,3]
# df['b']=[1,2,3,4,5,]
# print(df)

# %%
# %cd ..
# Out:
# /notebooks/v2

# %%
from lib.base import *
from lib.run.args import Args
from lib.run.plot import Plot, set_theme
# Out:
# Global seed set to 0

# %%
# %config InlineBackend.figure_format = 'svg'
n = 4
set_theme([n,n])

# %%
aa = []

# %%
x=io.load('csv/epoch=16.csv')

# %%
a = Args(
        splitter = 'Sequential',
        splitter_pp = dict(
            n_days_in_sample = 30,
            bank_quantile = 0.9,
            rtk_quantile = 0.9,
        ),    
        n_folds = 3,# 1000 == 'full train'
        fold = 0,
    
        fit_limit = 1.,
        val_limit = 1.,
    
        batch_size = 32,    
        lr = 2e-3,
        n_epochs = 10,
        check_val_every_n_epoch = 1,
    
        bb_pp = dict(
            block_size = 16,
            hidden_size = 128,
            intermediate_size = 128,
            num_attention_heads = 1,
            num_hidden_layers = 1,
            num_random_blocks = 1,
        ),
    
        loss = 'MarginLoss',
        loss_pp = dict(),
    
        use_unmatched = bool(0),
    
        miner = None,
        miner_pp = dict(),
    
        avg_loss = 'mean',
        avg_pred = 'mean',
)
a.update()
aa.append(a)
# Out:
# f8dc2a144b2ebdfd78e0626fdb789a3b

# %%
a = Args(
        splitter = 'Sequential',
        splitter_pp = dict(
            n_days_in_sample = 30,
            bank_quantile = 0.9,
            rtk_quantile = 0.9,
        ),    
        n_folds = 3,# 1000 == 'full train'
        fold = 0,
    
        fit_limit = 1.,
        val_limit = 1.,
    
        batch_size = 27,    
        lr = 1e-3,
        n_epochs = 20,
        check_val_every_n_epoch = 1,
    
        bb_pp = dict(
            block_size = 16,
            hidden_size = 128,
            intermediate_size = 128,
            num_attention_heads = 1,
            num_hidden_layers = 1,
            num_random_blocks = 1,
        ),
    
        loss = 'MarginLoss',
        loss_pp = dict(),
    
        use_unmatched = bool(0),
    
        miner = None,
        miner_pp = dict(),
    
        avg_loss = 'mean',
        avg_pred = 'mean',
)
a.update()
aa.append(a)
# Out:
# e4fc335312cd113c2cdf061611b9b367

# %%
a = Args(
        splitter = 'Sequential',
        splitter_pp = dict(
            n_days_in_sample = 30,
            bank_quantile = 0.9,
            rtk_quantile = 0.9,
        ),    
        n_folds = 5,# 1000 == 'full train'
        fold = 0,
    
        fit_limit = 1.,
        val_limit = 1.,
    
        batch_size = 32,    
        lr = 1e-3,
        n_epochs = 10**10,
        check_val_every_n_epoch = 1,
    
        bb_pp = dict(
            block_size = 16,
            hidden_size = 128,
            intermediate_size = 128,
            num_attention_heads = 1,
            num_hidden_layers = 1,
            num_random_blocks = 1,
        ),
    
        loss = 'MarginLoss',
        loss_pp = dict(),
    
        use_unmatched = bool(0),
    
        miner = None,
        miner_pp = dict(),
    
        avg_loss = 'mean',
        avg_pred = 'mean',
)
a.update()
aa.append(a)
# Out:
# 37da83ea18875cb3a42be3b547f5f43a

# %%
a = Args(
        splitter = 'Sequential',
        splitter_pp = dict(
            n_days_in_sample = 30,
            bank_quantile = 0.9,
            rtk_quantile = 0.9,
        ),    
        n_folds = 5,# 1000 == 'full train'
        fold = 0,
    
        fit_limit = 1.,
        val_limit = 1.,
    
        batch_size = 32,    
        lr = 5e-4,
        n_epochs = 10**10,
        check_val_every_n_epoch = 1,
    
        bb_pp = dict(
            block_size = 16,
            hidden_size = 128,
            intermediate_size = 128,
            num_attention_heads = 1,
            num_hidden_layers = 1,
            num_random_blocks = 1,
        ),
    
        loss = 'MarginLoss',
        loss_pp = dict(),
    
        use_unmatched = bool(0),
    
        miner = None,
        miner_pp = dict(),
    
        avg_loss = 'mean',
        avg_pred = 'mean',
)
a.update()
aa.append(a)
# Out:
# e58cc36966a649042c9eb93c0accc78a

# %%
a = Args(
        splitter = 'Sequential',
        splitter_pp = dict(
            n_days_in_sample = 30,
            bank_quantile = 0.9,
            rtk_quantile = 0.9,
        ),    
        n_folds = 5,# 1000 == 'full train'
        fold = 0,
    
        fit_limit = 1.,
        val_limit = 1.,
    
        batch_size = 32,    
        lr = 5e-4,
        n_epochs = 11,
        check_val_every_n_epoch = 1,
    
        bb_pp = dict(
            block_size = 16,
            hidden_size = 128,
            intermediate_size = 128,
            num_attention_heads = 1,
            num_hidden_layers = 1,
            num_random_blocks = 1,
        ),
    
        loss = 'MarginLoss',
        loss_pp = dict(),
    
        use_unmatched = bool(0),
    
        miner = None,
        miner_pp = dict(),
    
        avg_loss = 'mean',
        avg_pred = 'mean',
)
a.update()
aa.append(a)
# Out:
# 23928e48db2a0b2861062894b35613e4

# %%
a = Args(
        splitter = 'Sequential',
        splitter_pp = dict(
            n_days_in_sample = 30,
            bank_quantile = 0.9,
            rtk_quantile = 0.9,
        ),    
        n_folds = 5,# 1000 == 'full train'
        fold = 0,
    
        fit_limit = 1.,
        val_limit = 1.,
    
        batch_size = 32,    
        lr = 2e-3,
        n_epochs = 10**10,
        check_val_every_n_epoch = 1,
    
        bb_pp = dict(
            block_size = 16,
            hidden_size = 128,
            intermediate_size = 128,
            num_attention_heads = 1,
            num_hidden_layers = 1,
            num_random_blocks = 1,
        ),
    
        loss = 'MarginLoss',
        loss_pp = dict(),
    
        use_unmatched = bool(0),
    
        miner = None,
        miner_pp = dict(),
    
        avg_loss = 'mean',
        avg_pred = 'mean',
)
a.update()
aa.append(a)
# Out:
# 45efa34ac7bee660caef0c6b04b36d31

# %%
a = Args(
        splitter = 'Sequential',
        splitter_pp = dict(
            n_days_in_sample = 30,
            bank_quantile = 0.9,
            rtk_quantile = 0.9,
        ),    
        n_folds = 3,# 1000 == 'full train'
        fold = 0,
    
        fit_limit = 1.,
        val_limit = 1.,
    
        batch_size = 32,    
        lr = 1e-3,
        n_epochs = 10**10,
        check_val_every_n_epoch = 1,
    
        bb_pp = dict(
            block_size = 16,
            hidden_size = 128,
            intermediate_size = 128,
            num_attention_heads = 1,
            num_hidden_layers = 1,
            num_random_blocks = 1,
        ),
    
        loss = 'MarginLoss',
        loss_pp = dict(),
    
        use_unmatched = bool(0),
    
        miner = None,
        miner_pp = dict(),
    
        avg_loss = 'mean',
        avg_pred = 'mean',
)
a.update()
aa.append(a)
# Out:
# a8aa7c70c8a1b285adb0057cbe3cb921

# %%
import os
sorted(os.listdir(f'log/{aa[-1].exp_name}/version_0/checkpoints'))
# Out:
# ['epoch=0.ckpt',
#  'epoch=1.ckpt',
#  'epoch=10.ckpt',
#  'epoch=11.ckpt',
#  'epoch=12.ckpt',
#  'epoch=13.ckpt',
#  'epoch=14.ckpt',
#  'epoch=15.ckpt',
#  'epoch=16.ckpt',
#  'epoch=17.ckpt',
#  'epoch=18.ckpt',
#  'epoch=19.ckpt',
#  'epoch=2.ckpt',
#  'epoch=20.ckpt',
#  'epoch=21.ckpt',
#  'epoch=22.ckpt',
#  'epoch=23.ckpt',
#  'epoch=24.ckpt',
#  'epoch=25.ckpt',
#  'epoch=26.ckpt',
#  'epoch=27.ckpt',
#  'epoch=28.ckpt',
#  'epoch=29.ckpt',
#  'epoch=3.ckpt',
#  'epoch=30.ckpt',
#  'epoch=31.ckpt',
#  'epoch=32.ckpt',
#  'epoch=33.ckpt',
#  'epoch=34.ckpt',
#  'epoch=35.ckpt',
#  'epoch=36.ckpt',
#  'epoch=37.ckpt',
#  'epoch=38.ckpt',
#  'epoch=39.ckpt',
#  'epoch=4.ckpt',
#  'epoch=40.ckpt',
#  'epoch=41.ckpt',
#  'epoch=42.ckpt',
#  'epoch=43.ckpt',
#  'epoch=44.ckpt',
#  'epoch=45.ckpt',
#  'epoch=46.ckpt',
#  'epoch=47.ckpt',
#  'epoch=48.ckpt',
#  'epoch=49.ckpt',
#  'epoch=5.ckpt',
#  'epoch=50.ckpt',
#  'epoch=6.ckpt',
#  'epoch=7.ckpt',
#  'epoch=8.ckpt',
#  'epoch=9.ckpt']

# %%
# !ls log/{aa[-1].exp_name}/version_0/checkpoints
# Out:
# 'epoch=0.ckpt'	 'epoch=20.ckpt'  'epoch=32.ckpt'  'epoch=44.ckpt'
# 'epoch=1.ckpt'	 'epoch=21.ckpt'  'epoch=33.ckpt'  'epoch=45.ckpt'
# 'epoch=10.ckpt'  'epoch=22.ckpt'  'epoch=34.ckpt'  'epoch=46.ckpt'
# 'epoch=11.ckpt'  'epoch=23.ckpt'  'epoch=35.ckpt'  'epoch=47.ckpt'
# 'epoch=12.ckpt'  'epoch=24.ckpt'  'epoch=36.ckpt'  'epoch=48.ckpt'
# 'epoch=13.ckpt'  'epoch=25.ckpt'  'epoch=37.ckpt'  'epoch=49.ckpt'
# 'epoch=14.ckpt'  'epoch=26.ckpt'  'epoch=38.ckpt'  'epoch=5.ckpt'
# 'epoch=15.ckpt'  'epoch=27.ckpt'  'epoch=39.ckpt'  'epoch=50.ckpt'
# 'epoch=16.ckpt'  'epoch=28.ckpt'  'epoch=4.ckpt'   'epoch=6.ckpt'
# 'epoch=17.ckpt'  'epoch=29.ckpt'  'epoch=40.ckpt'  'epoch=7.ckpt'
# 'epoch=18.ckpt'  'epoch=3.ckpt'   'epoch=41.ckpt'  'epoch=8.ckpt'
# 'epoch=19.ckpt'  'epoch=30.ckpt'  'epoch=42.ckpt'  'epoch=9.ckpt'
# 'epoch=2.ckpt'	 'epoch=31.ckpt'  'epoch=43.ckpt'

# %%
'506 K'
'19 s'
(2*60+45)*20/60
# Out:
# 55.0

# %%
x = io.load(f'log/{aa[-1].exp_name}/version_0/metrics.csv')
print(x['R1'])
# Out:
# 0     0.006562
# 1     0.008111
# 2     0.008443
# 3     0.010547
# 4     0.009600
# 5     0.010988
# 6     0.011995
# 7     0.011263
# 8     0.011341
# 9     0.012666
# 10    0.013690
# 11    0.012437
# 12    0.012735
# 13    0.012908
# 14    0.011799
# 15    0.012022
# 16    0.012126
# 17    0.012847
# 18    0.012197
# 19    0.013195
# 20    0.012362
# 21    0.013407
# 22    0.014055
# 23    0.011841
# 24    0.013516
# 25    0.011961
# 26    0.012848
# 27    0.012318
# 28    0.011885
# 29    0.011812
# 30    0.011562
# 31    0.012541
# 32    0.012518
# 33    0.011359
# 34    0.012364
# 35    0.011747
# 36    0.010641
# 37    0.011379
# 38    0.012268
# 39    0.012170
# 40    0.011613
# 41    0.011134
# 42    0.010220
# 43    0.011801
# 44    0.011235
# 45    0.010482
# 46    0.011116
# 47    0.012022
# 48    0.011515
# 49    0.010574
# 50    0.011609
# Name: R1, dtype: float64

# %%
plot = Plot(aa[:],0,50)

# %%
plot('R1')

# %%
plot('MRR')

# %%
plot('P')

# %%
plot('loss')
