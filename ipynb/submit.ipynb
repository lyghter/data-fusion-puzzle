# %%
# %cd ../..
# Out:
# /notebooks

# %%
# !rm v3.zip
# Out:
# rm: cannot remove 'v3.zip': No such file or directory

# %%
# !zip -r v3.zip v3 \
-x 'v3/data/*' \
-x 'v3/.ipynb_checkpoints/*' \
-x 'v3/.git/*'
# Out:
#   adding: v3/ (stored 0%)
#   adding: v3/json/ (stored 0%)
#   adding: v3/json/uid_i2v.json (deflated 51%)
#   adding: v3/json/event_v2i.json (deflated 73%)
#   adding: v3/json/uid_v2i.json (deflated 49%)
#   adding: v3/json/event_i2v.json (deflated 75%)
#   adding: v3/README.md (deflated 64%)
#   adding: v3/Untitled.ipynb (deflated 75%)
#   adding: v3/run.sh (deflated 13%)
#   adding: v3/model.cbm (deflated 52%)
#   adding: v3/run.py (deflated 23%)
#   adding: v3/metadata.json (deflated 7%)
#   adding: v3/ipynb/ (stored 0%)
#   adding: v3/ipynb/debug.ipynb (deflated 77%)
#   adding: v3/ipynb/run.ipynb (deflated 62%)
#   adding: v3/ipynb/plot.ipynb (deflated 87%)
#   adding: v3/ipynb/main.ipynb (deflated 82%)
#   adding: v3/ipynb/submit.ipynb (deflated 21%)
#   adding: v3/ipynb/.ipynb_checkpoints/ (stored 0%)
#   adding: v3/ipynb/.ipynb_checkpoints/submit-checkpoint.ipynb (deflated 21%)
#   adding: v3/ipynb/.ipynb_checkpoints/debug-checkpoint.ipynb (deflated 77%)
# ...
